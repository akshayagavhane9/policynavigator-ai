# %%
df = read_jsonl("../data/synthetic_eval/eval_results.jsonl")
summary = json.load(open("../data/synthetic_eval/metrics_summary.json"))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 df = read_jsonl("../data/synthetic_eval/eval_results.jsonl")
#       2 summary = json.load(open("../data/synthetic_eval/metrics_summary.json"))
#
# NameError: name 'read_jsonl' is not defined
